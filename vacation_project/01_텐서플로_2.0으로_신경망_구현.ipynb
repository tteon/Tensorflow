# %% [markdown]
# # 신경망

# %% [markdown]
# ## 텐서플로 2.0의 단순 신경망을 은닉층으로 개선
#
# 계층을 추가하면 매개변수가 추가돼 모델이 더 복잡한 패턴을 기억할 수 있게 됨.
#
# * 추가 계층은 입력 또는 출력과 직접 연결되지 않기 때문에 숨겨진 것으로 간주됨. 첫 번째 은닉층 뒤에 N_HIDDEN뉴런을 가진 두 번째 은닉층이 있고 그 다음으로 10개의 뉴런을 가진 출력 계층이 있음.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784
X_train = X_train.reshape(60000 ,RESHAPED).astype('float32')
X_test = X_test.reshape(10000 ,RESHAPED).astype('float32')

X_train, X_test = X_train / 255.0 , X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_train.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
                            input_shape=(RESHAPED,),
                            name='dense_layer', activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN,
                            name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES,
                            name='dense_layer_3', activation='softmax'))

model.summary()

model.compile(optimizer='SGD',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train, Y_train,
         batch_size=BATCH_SIZE, epochs=EPOCHS,
         verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 60000 train samples
# 60000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3748 - accuracy: 0.6764 - val_loss: 0.6958 - val_accuracy: 0.8512
# Epoch 2/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.5725 - accuracy: 0.8558 - val_loss: 0.4432 - val_accuracy: 0.8848
# Epoch 3/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4311 - accuracy: 0.8824 - val_loss: 0.3691 - val_accuracy: 0.8998
# Epoch 4/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3752 - accuracy: 0.8957 - val_loss: 0.3337 - val_accuracy: 0.9076
# Epoch 5/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3435 - accuracy: 0.9025 - val_loss: 0.3105 - val_accuracy: 0.9131
# Epoch 6/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3210 - accuracy: 0.9082 - val_loss: 0.2936 - val_accuracy: 0.9178
# Epoch 7/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3041 - accuracy: 0.9129 - val_loss: 0.2793 - val_accuracy: 0.9215
# Epoch 8/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2895 - accuracy: 0.9164 - val_loss: 0.2694 - val_accuracy: 0.9246
# Epoch 9/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2775 - accuracy: 0.9199 - val_loss: 0.2598 - val_accuracy: 0.9259
# Epoch 10/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2664 - accuracy: 0.9236 - val_loss: 0.2487 - val_accuracy: 0.9291
# Epoch 11/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2565 - accuracy: 0.9265 - val_loss: 0.2422 - val_accuracy: 0.9300
# Epoch 12/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2475 - accuracy: 0.9290 - val_loss: 0.2345 - val_accuracy: 0.9330
# Epoch 13/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2392 - accuracy: 0.9311 - val_loss: 0.2289 - val_accuracy: 0.9337
# Epoch 14/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2318 - accuracy: 0.9330 - val_loss: 0.2216 - val_accuracy: 0.9377
# Epoch 15/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2246 - accuracy: 0.9355 - val_loss: 0.2155 - val_accuracy: 0.9383
# Epoch 16/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2178 - accuracy: 0.9375 - val_loss: 0.2106 - val_accuracy: 0.9400
# Epoch 17/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2117 - accuracy: 0.9391 - val_loss: 0.2051 - val_accuracy: 0.9427
# Epoch 18/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2055 - accuracy: 0.9410 - val_loss: 0.2026 - val_accuracy: 0.9427
# Epoch 19/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2000 - accuracy: 0.9427 - val_loss: 0.1960 - val_accuracy: 0.9461
# Epoch 20/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1947 - accuracy: 0.9437 - val_loss: 0.1913 - val_accuracy: 0.9454
# Epoch 21/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1894 - accuracy: 0.9456 - val_loss: 0.1875 - val_accuracy: 0.9476
# Epoch 22/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1845 - accuracy: 0.9465 - val_loss: 0.1846 - val_accuracy: 0.9492
# Epoch 23/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1800 - accuracy: 0.9487 - val_loss: 0.1801 - val_accuracy: 0.9505
# Epoch 24/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1756 - accuracy: 0.9490 - val_loss: 0.1765 - val_accuracy: 0.9508
# Epoch 25/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1712 - accuracy: 0.9504 - val_loss: 0.1738 - val_accuracy: 0.9520
# Epoch 26/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1671 - accuracy: 0.9516 - val_loss: 0.1697 - val_accuracy: 0.9533
# Epoch 27/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1633 - accuracy: 0.9533 - val_loss: 0.1681 - val_accuracy: 0.9533
# Epoch 28/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1594 - accuracy: 0.9545 - val_loss: 0.1644 - val_accuracy: 0.9537
# Epoch 29/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1560 - accuracy: 0.9550 - val_loss: 0.1617 - val_accuracy: 0.9548
# Epoch 30/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1522 - accuracy: 0.9569 - val_loss: 0.1600 - val_accuracy: 0.9553
# Epoch 31/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1489 - accuracy: 0.9573 - val_loss: 0.1571 - val_accuracy: 0.9559
# Epoch 32/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1460 - accuracy: 0.9585 - val_loss: 0.1539 - val_accuracy: 0.9575
# Epoch 33/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1426 - accuracy: 0.9590 - val_loss: 0.1515 - val_accuracy: 0.9583
# Epoch 34/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1396 - accuracy: 0.9601 - val_loss: 0.1500 - val_accuracy: 0.9588
# Epoch 35/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1367 - accuracy: 0.9611 - val_loss: 0.1478 - val_accuracy: 0.9589
# Epoch 36/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1337 - accuracy: 0.9619 - val_loss: 0.1456 - val_accuracy: 0.9593
# Epoch 37/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1312 - accuracy: 0.9622 - val_loss: 0.1436 - val_accuracy: 0.9611
# Epoch 38/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1286 - accuracy: 0.9634 - val_loss: 0.1427 - val_accuracy: 0.9602
# Epoch 39/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1260 - accuracy: 0.9640 - val_loss: 0.1400 - val_accuracy: 0.9607
# Epoch 40/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1236 - accuracy: 0.9650 - val_loss: 0.1388 - val_accuracy: 0.9616
# Epoch 41/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1212 - accuracy: 0.9655 - val_loss: 0.1377 - val_accuracy: 0.9613
# Epoch 42/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1189 - accuracy: 0.9667 - val_loss: 0.1350 - val_accuracy: 0.9630
# Epoch 43/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1165 - accuracy: 0.9673 - val_loss: 0.1341 - val_accuracy: 0.9634
# Epoch 44/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1146 - accuracy: 0.9674 - val_loss: 0.1314 - val_accuracy: 0.9643
# Epoch 45/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1123 - accuracy: 0.9681 - val_loss: 0.1313 - val_accuracy: 0.9642
# Epoch 46/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1104 - accuracy: 0.9690 - val_loss: 0.1291 - val_accuracy: 0.9653
# Epoch 47/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1084 - accuracy: 0.9696 - val_loss: 0.1277 - val_accuracy: 0.9653
# Epoch 48/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1064 - accuracy: 0.9703 - val_loss: 0.1276 - val_accuracy: 0.9649
# Epoch 49/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1047 - accuracy: 0.9706 - val_loss: 0.1256 - val_accuracy: 0.9657
# Epoch 50/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1025 - accuracy: 0.9714 - val_loss: 0.1248 - val_accuracy: 0.9660
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9646
# Test accuracy: 0.9646000266075134

# %% [markdown]
# ## 텐서플로에서 드롭아웃으로 단순망 개선
#
# 무작위 드롭아웃으로 신경망의 일반화를 향상시키는데 도움이 되는 유용한 중복 패턴을 학습시킨다는 것.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2
DROPOUT = 0.3

mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784
X_train = X_train.reshape(60000 ,RESHAPED).astype('float32')
X_test = X_test.reshape(10000 ,RESHAPED).astype('float32')

X_train, X_test = X_train / 255.0 , X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_train.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
                            input_shape=(RESHAPED,),
                            name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
                            name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
                            name='dense_layer_3', activation='softmax'))

model.summary()

model.compile(optimizer='SGD',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train, Y_train,
         batch_size=BATCH_SIZE, epochs=EPOCHS,
         verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f'Test accuracy: {test_acc}')
# Out:
#
50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2177 - accuracy: 0.9371 - val_loss: 0.1473 - val_accuracy: 0.9571
# Epoch 37/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2134 - accuracy: 0.9375 - val_loss: 0.1457 - val_accuracy: 0.9567
# Epoch 38/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2121 - accuracy: 0.9379 - val_loss: 0.1432 - val_accuracy: 0.9575
# Epoch 39/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2084 - accuracy: 0.9384 - val_loss: 0.1415 - val_accuracy: 0.9579
# Epoch 40/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2048 - accuracy: 0.9405 - val_loss: 0.1400 - val_accuracy: 0.9580
# Epoch 41/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1996 - accuracy: 0.9415 - val_loss: 0.1391 - val_accuracy: 0.9580
# Epoch 42/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2025 - accuracy: 0.9398 - val_loss: 0.1380 - val_accuracy: 0.9583
# Epoch 43/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1991 - accuracy: 0.9419 - val_loss: 0.1358 - val_accuracy: 0.9588
# Epoch 44/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1938 - accuracy: 0.9428 - val_loss: 0.1348 - val_accuracy: 0.9588
# Epoch 45/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1951 - accuracy: 0.9425 - val_loss: 0.1335 - val_accuracy: 0.9600
# Epoch 46/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1911 - accuracy: 0.9443 - val_loss: 0.1318 - val_accuracy: 0.9611
# Epoch 47/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1890 - accuracy: 0.9449 - val_loss: 0.1312 - val_accuracy: 0.9604
# Epoch 48/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1867 - accuracy: 0.9447 - val_loss: 0.1298 - val_accuracy: 0.9615
# Epoch 49/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1862 - accuracy: 0.9450 - val_loss: 0.1282 - val_accuracy: 0.9619
# Epoch 50/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1829 - accuracy: 0.9463 - val_loss: 0.1274 - val_accuracy: 0.9625
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1267 - accuracy: 0.9617
# Test accuracy: 0.9617000222206116

# %% [markdown]
# 훈련 정확도는 테스트 정확도보다는 높아야 한다. 그렇지 않다면 충분히 오랫동안 훈련을 받지 못한 것일 수 있음.
# - 에폭의 수를 좀 더 늘려야 함. 그러나 바로 에폭을 늘리기 전에 훈련이 더 빨리 수렴될 수 있또록 몇 가지 다른 개념을 도입할 필요가 있음.

# %% [markdown]
# ## 텐서플로 2.0에서 여러 최적화기 테스트
#
# 도랑찾기.

# %%
# RMSProp optimizer

import tensorflow as tf
import numpy as np
from tensorflow import keras

EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2
DROPOUT = 0.3

mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784
X_train = X_train.reshape(60000 ,RESHAPED).astype('float32')
X_test = X_test.reshape(10000 ,RESHAPED).astype('float32')

X_train, X_test = X_train / 255.0 , X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_train.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
                            input_shape=(RESHAPED,),
                            name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
                            name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
                            name='dense_layer_3', activation='softmax'))

model.summary()

model.compile(optimizer='RMSProp',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train, Y_train,
         batch_size=BATCH_SIZE, epochs=EPOCHS,
         verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 60000 train samples
# 60000 test samples
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4721 - accuracy: 0.8579 - val_loss: 0.1747 - val_accuracy: 0.9489
# Epoch 2/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2258 - accuracy: 0.9339 - val_loss: 0.1361 - val_accuracy: 0.9607
# Epoch 3/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1763 - accuracy: 0.9482 - val_loss: 0.1164 - val_accuracy: 0.9653
# Epoch 4/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1504 - accuracy: 0.9559 - val_loss: 0.1071 - val_accuracy: 0.9688
# Epoch 5/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1331 - accuracy: 0.9615 - val_loss: 0.1053 - val_accuracy: 0.9688
# Epoch 6/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1208 - accuracy: 0.9651 - val_loss: 0.0994 - val_accuracy: 0.9710
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1088 - accuracy: 0.9679 - val_loss: 0.0997 - val_accuracy: 0.9739
# Epoch 8/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.
50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0540 - accuracy: 0.9848 - val_loss: 0.1512 - val_accuracy: 0.9776
# Epoch 41/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0527 - accuracy: 0.9849 - val_loss: 0.1369 - val_accuracy: 0.9790
# Epoch 42/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0519 - accuracy: 0.9853 - val_loss: 0.1574 - val_accuracy: 0.9764
# Epoch 43/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0557 - accuracy: 0.9852 - val_loss: 0.1462 - val_accuracy: 0.9775
# Epoch 44/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0542 - accuracy: 0.9854 - val_loss: 0.1629 - val_accuracy: 0.9773
# Epoch 45/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0525 - accuracy: 0.9858 - val_loss: 0.1550 - val_accuracy: 0.9768
# Epoch 46/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0505 - accuracy: 0.9858 - val_loss: 0.1515 - val_accuracy: 0.9791
# Epoch 47/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0528 - accuracy: 0.9861 - val_loss: 0.1468 - val_accuracy: 0.9774
# Epoch 48/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0538 - accuracy: 0.9852 - val_loss: 0.1626 - val_accuracy: 0.9772
# Epoch 49/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0561 - accuracy: 0.9856 - val_loss: 0.1549 - val_accuracy: 0.9780
# Epoch 50/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0518 - accuracy: 0.9859 - val_loss: 0.1633 - val_accuracy: 0.9780
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1391 - accuracy: 0.9784
# Test accuracy: 0.9783999919891357

# %%
#  Adam optimizer

import tensorflow as tf
import numpy as np
from tensorflow import keras

EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2
DROPOUT = 0.3

mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784
X_train = X_train.reshape(60000 ,RESHAPED).astype('float32')
X_test = X_test.reshape(10000 ,RESHAPED).astype('float32')

X_train, X_test = X_train / 255.0 , X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_train.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
                            input_shape=(RESHAPED,),
                            name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
                            name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
                            name='dense_layer_3', activation='softmax'))

model.summary()

model.compile(optimizer='Adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train, Y_train,
         batch_size=BATCH_SIZE, epochs=EPOCHS,
         verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 60000 train samples
# 60000 test samples
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5216 - accuracy: 0.8408 - val_loss: 0.1911 - val_accuracy: 0.9455
# Epoch 2/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2334 - accuracy: 0.9308 - val_loss: 0.1404 - val_accuracy: 0.9593
# Epoch 3/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1811 - accuracy: 0.9470 - val_loss: 0.1220 - val_accuracy: 0.9648
# Epoch 4/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1501 - accuracy: 0.9546 - val_loss: 0.1097 - val_accuracy: 0.9676
# Epoch 5/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1300 - accuracy: 0.9607 - val_loss: 0.0968 - val_accuracy: 0.9720
# Epoch 6/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1140 - accuracy: 0.9661 - val_loss: 0.0937 - val_accuracy: 0.9725
# Epoch 7/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1059 - accuracy: 0.9678 - val_loss: 0.0905 - val_accuracy: 0.9740
# Epoch 8/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0975 - accuracy: 0.9698 - val_loss: 0.0890 - val_accuracy: 0.9758
# Epoch 9/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0887 - accuracy: 0.9721 - val_loss: 0.0852 - val_accuracy: 0.9756
# Epoch 10/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0850 - accuracy: 0.9733 - val_loss: 0.0853 - val_accuracy: 0.9760
# Epoch 11/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0785 - accuracy: 0.9761 - val_loss: 0.0889 - val_accuracy: 0.9751
# Epoch 12/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0749 - accuracy: 0.9766 - val_loss: 0.0844 - val_accuracy: 0.9765
# Epoch 13/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0742 - accuracy: 0.9762 - val_loss: 0.0882 - val_accuracy: 0.9743
# Epoch 14/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0666 - accuracy: 0.9785 - val_loss: 0.0821 - val_accuracy: 0.9783
# Epoch 15/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0665 - accuracy: 0.9786 - val_loss: 0.0850 - val_accuracy: 0.9761
# Epoch 16/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0618 - accuracy: 0.9797 - val_loss: 0.0839 - val_accuracy: 0.9751
# Epoch 17/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0574 - accuracy: 0.9814 - val_loss: 0.0879 - val_accuracy: 0.9756
# Epoch 18/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0608 - accuracy: 0.9805 - val_loss: 0.0875 - val_accuracy: 0.9768
# Epoch 19/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0560 - accuracy: 0.9816 - val_loss: 0.0868 - val_accuracy: 0.9766
# Epoch 20/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0540 - accuracy: 0.9822 - val_loss: 0.0809 - val_accuracy: 0.9778
# Epoch 21/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0503 - accuracy: 0.9833 - val_loss: 0.0873 - val_accuracy: 0.9780
# Epoch 22/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0540 - accuracy: 0.9820 - val_loss: 0.0862 - val_accuracy: 0.9778
# Epoch 23/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0493 - accuracy: 0.9841 - val_loss: 0.0798 - val_accuracy: 0.9797
# Epoch 24/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0484 - accuracy: 0.9841 - val_loss: 0.0830 - val_accuracy: 0.9781
# Epoch 25/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0450 - accuracy: 0.9852 - val_loss: 0.0797 - val_accuracy: 0.9803
# Epoch 26/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0429 - accuracy: 0.9859 - val_loss: 0.0819 - val_accuracy: 0.9783
# Epoch 27/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0450 - accuracy: 0.9846 - val_loss: 0.0856 - val_accuracy: 0.9779
# Epoch 28/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0425 - accuracy: 0.9863 - val_loss: 0.0868 - val_accuracy: 0.9787
# Epoch 29/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0440 - accuracy: 0.9848 - val_loss: 0.0834 - val_accuracy: 0.9795
# Epoch 30/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0404 - accuracy: 0.9866 - val_loss: 0.0868 - val_accuracy: 0.9785
# Epoch 31/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0385 - accuracy: 0.9875 - val_loss: 0.0907 - val_accuracy: 0.9762
# Epoch 32/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0393 - accuracy: 0.9872 - val_loss: 0.0867 - val_accuracy: 0.9791
# Epoch 33/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 0.0895 - val_accuracy: 0.9797
# Epoch 34/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0411 - accuracy: 0.9866 - val_loss: 0.0874 - val_accuracy: 0.9784
# Epoch 35/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0379 - accuracy: 0.9879 - val_loss: 0.0947 - val_accuracy: 0.9784
# Epoch 36/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0389 - accuracy: 0.9872 - val_loss: 0.0934 - val_accuracy: 0.9778
# Epoch 37/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0374 - accuracy: 0.9879 - val_loss: 0.0890 - val_accuracy: 0.9789
# Epoch 38/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0347 - accuracy: 0.9885 - val_loss: 0.0913 - val_accuracy: 0.9786
# Epoch 39/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0346 - accuracy: 0.9885 - val_loss: 0.0953 - val_accuracy: 0.9786
# Epoch 40/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0367 - accuracy: 0.9879 - val_loss: 0.0916 - val_accuracy: 0.9783
# Epoch 41/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0365 - accuracy: 0.9871 - val_loss: 0.0860 - val_accuracy: 0.9801
# Epoch 42/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0353 - accuracy: 0.9885 - val_loss: 0.0927 - val_accuracy: 0.9807
# Epoch 43/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0333 - accuracy: 0.9888 - val_loss: 0.0892 - val_accuracy: 0.9791
# Epoch 44/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0324 - accuracy: 0.9890 - val_loss: 0.0950 - val_accuracy: 0.9789
# Epoch 45/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0320 - accuracy: 0.9895 - val_loss: 0.0925 - val_accuracy: 0.9784
# Epoch 46/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0323 - accuracy: 0.9895 - val_loss: 0.0917 - val_accuracy: 0.9801
# Epoch 47/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.0950 - val_accuracy: 0.9787
# Epoch 48/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.0990 - val_accuracy: 0.9788
# Epoch 49/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0289 - accuracy: 0.9901 - val_loss: 0.0992 - val_accuracy: 0.9788
# Epoch 50/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0310 - accuracy: 0.9898 - val_loss: 0.0955 - val_accuracy: 0.9795
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0808 - accuracy: 0.9806
# Test accuracy: 0.9805999994277954

# %% [markdown]
# ## 에폭 수 증가시키기

# %% [markdown]
# ## 최적화기 학습률 조절

# %% [markdown]
# ## 내부 은닉층 개수 증가

# %% [markdown]
# ## 배치 계산 크기 증가

# %% [markdown]
# # 정규화

# %% [markdown]
# ## 과적합을 피하기 위한 정규화 적용
#
# 복잡도의 증가는 두 가지 부정적인 결과를 초래할 수 있음.
#
# 1. 복잡한 모델을 실행하려면 상당한 시간이 소요될 수 있음.
#
#
# 2. 복잡한 모델은 훈련 데이터에서는 매우 우수한 성과를 달성할 수 있지만 검증 데이터에서는 상당히 나쁜 성과를 거둘 수 있음.
#
# 머신러닝 모델 정규화 3가지
#
# - L1 정규화 ; 절댓값
#
# - L2 정규화 ; 제곱
#
# - 일래스틱 정규화 ; 앞 선 두 기법의 조합

# %% [markdown]
# ## 배치 정규화의 이해
#
# 배치 정규화는 또 다른 형태의 정규화.
#
# 훈련 과정에서 초기 계층의 가중치는 변경될 것이 당연하므로 이후 계층의 입력은 크게 변경될 수 있음.
#
# 즉 , 각 계층은 모든 배치마다 가중치를 지속적으로 다른 분포로 다시 조정해야 함.
#
# 이로 인해 모델의 훈련 속도가 크게 떨어질 수 있음.
#
# __핵심 아이디어는 각 배치와 각 에폭에 대해 계층 입력이 좀 더 유사한 분포를 갖게 하자는 것임.__
#
# 또 다른 문제는 시그모이드 활성화 함수는 0 근처에서 아주 잘 작동하나 값이 0 에서 상당히 멀어지면 ' 고착 ' 되는 경향이 있음. ; 해당 뉴런은 자신의 가중치를 갱신할 수 없게 됨.
#
# -->계층 출력을 0에 가까운 가우시안 분포 단위로 변환 하는 것.

# %% [markdown]
# # 감정 분석

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, preprocessing
import tensorflow_datasets as tfds

max_len = 200
n_words = 10000
dim_embedding = 256
EPOCHS = 20
BATCH_SIZE = 500

def load_data():
    (X_train, y_train), (X_test, y_test) = datasets.imdb.load_data(num_words=n_words)
    X_train = preprocessing.sequence.pad_sequences(X_train,maxlen=max_len)
    X_test = preprocessing.sequence.pad_sequences(X_test,maxlen=max_len)
    return (X_train, y_train), (X_test, y_test)

# %%
def build_model():
    model = models.Sequential()
    # 입력 ; embedding layer
    # 모델의 크기의 정수 행렬을 입력으로 취함 (batch , input_length)
    # 모델의 출력은 차원 ( input_length , dim_embedding )
    # 입력 중 가장 큰 정수는 n_words보다 작거나 같음.
    model.add(layers.Embedding(n_words, dim_embedding, input_length=max_len))
    model.add(layers.Dropout(0.3))
    # 각 n_words 특징에서 특징 벡터의 최댓값을 취함.
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
(X_train, y_train), (X_test, y_test) = load_data()
model = build_model()
model.summary()

model.compile(optimizer = 'adam',
             loss='binary_crossentropy',
             metrics = ['accuracy'])

score = model.fit(X_train, y_train,
                  epochs = EPOCHS,
                  batch_size = BATCH_SIZE,
                  validation_data = (X_test, y_test))

score = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
print(f'\nTest score: {score[0]}')
print(f'Test accuracy: {score[1]}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 2s 0us/step
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 256)          2560000
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 200, 256)          0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,593,025
# Trainable params: 2,593,025
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 50/50 [==============================] - 4s 74ms/step - loss: 0.6726 - accuracy: 0.6270 - val_loss: 0.6313 - val_accuracy: 0.7769
# Epoch 2/20
# 50/50 [==============================] - 3s 68ms/step - loss: 0.4635 - accuracy: 0.8369 - val_loss: 0.3675 - val_accuracy: 0.8568
# Epoch 3/20
# 50/50 [==============================] - 3s 64ms/step - loss: 0.2855 - accuracy: 0.8825 - val_loss: 0.3061 - val_accuracy: 0.8744
# Epoch 4/20
# 50/50 [==============================] - 3s 64ms/step - loss: 0.2192 - accuracy: 0.9163 - val_loss: 0.2928 - val_accuracy: 0.8774
# Epoch 5/20
# 50/50 [==============================] - 3s 65ms/step - loss: 0.1741 - accuracy: 0.9364 - val_loss: 0.2894 - val_accuracy: 0.8760
# Epoch 6/20
# 50/50 [==============================] - 3s 66ms/step - loss: 0.1359 - accuracy: 0.9532 - val_loss: 0.2928 - val_accuracy: 0.8738
# Epoch 7/20
# 50/50 [==============================] - 3s 66ms/step - loss: 0.1053 - accuracy: 0.9666 - val_loss: 0.3129 - val_accuracy: 0.8656
# Epoch 8/20
# 50/50 [==============================] - 3s 66ms/step - loss: 0.0793 - accuracy: 0.9765 - val_loss: 0.3193 - val_accuracy: 0.8668
# Epoch 9/20
# 50/50 [==============================] - 3s 63ms/step - loss: 0.0603 - accuracy: 0.9840 - val_loss: 0.3335 - val_accuracy: 0.8632
# Epoch 10/20
# 50/50 [==============================] - 3s 65ms/step - loss: 0.0440 - accuracy: 0.9897 - val_loss: 0.3520 - val_accuracy: 0.8602
# Epoch 11/20
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0352 - accuracy: 0.9914 - val_loss: 0.3661 - val_accuracy: 0.8592
# Epoch 12/20
# 50/50 [==============================] - 3s 66ms/step - loss: 0.0256 - accuracy: 0.9945 - val_loss: 0.3839 - val_accuracy: 0.8562
# Epoch 13/20
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0201 - accuracy: 0.9963 - val_loss: 0.3982 - val_accuracy: 0.8558
# Epoch 14/20
# 50/50 [==============================] - 3s 67ms/step - loss: 0.0161 - accuracy: 0.9969 - val_loss: 0.4160 - val_accuracy: 0.8544
# Epoch 15/20
# 50/50 [==============================] - 3s 66ms/step - loss: 0.0123 - accuracy: 0.9980 - val_loss: 0.4305 - val_accuracy: 0.8542
# Epoch 16/20
# 50/50 [==============================] - 3s 65ms/step - loss: 0.0097 - accuracy: 0.9988 - val_loss: 0.4458 - val_accuracy: 0.8533
# Epoch 17/20
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.4569 - val_accuracy: 0.8524
# Epoch 18/20
# 50/50 [==============================] - 3s 65ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 0.4669 - val_accuracy: 0.8524
# Epoch 19/20
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0062 - accuracy: 0.9992 - val_loss: 0.4826 - val_accuracy: 0.8504
# Epoch 20/20
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 0.4942 - val_accuracy: 0.8512
# 50/50 [==============================] - 1s 14ms/step - loss: 0.4942 - accuracy: 0.8512
#
# Test score: 0.4941892921924591
# Test accuracy: 0.8511999845504761

# %% [markdown]
# # 출력 예측
#
# - model.evaluate() 는 손실 값을 계산하는데 사용함.
#
#
#
# - model.predict_class() 는 범주 출력을 계산
#
#
#
# - model.predict_proba() 부류 확률을 계산하는 데 사용함.

# %% [markdown]
# # 역전파에 대한 실용적 개괄
#
# 다층 퍼셉트론은 역전파라는 프로세스를 통해 훈련 데이터에서 학습함.
#
# --> 오류가 발견되는 즉시 점진적으로 수정해 나가는 방법.
#
# 처음에는 모든 가중치에 __임의의 값__을 할당함.
#
# 그런 다음 훈련 집합의 각 입력에 대해 신경망이 활성화됨.
#
# 값은 입력 단계에서 은닉 단계를 통해 출력 단계로 순전파되어 예측이 이뤄짐.
#
# 훈련 집합에서 실제 관측값을 알기 때문에 예측에서 발생한 오차를 계산할 수 있음.
#
# __역전파의 핵심 아이디어__
#
# 그레디언트 하강과 같은 적절한 최적화 알고리즘을 사용해 오차를 줄이려는 목적으로 신경망 가중치를 조정하고자 오차를 역으로 전파하는 것임.
#
# __신경망에서 실제로 중요한 것은 단일 뉴런의 출력이 아니라 각 계층에서 조정된 종합적인 가중치임.__
